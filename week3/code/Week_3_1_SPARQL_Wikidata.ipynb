# %% [markdown]
# # **openHPI Course: Knowledge Graphs 2023**
#
# ## **Week 3: Querying Knowledge Graphs with SPARQL**
# ### **Notebook 3.1: Wikidata**
# ---
#
# This is the python notebook for week 3 (Querying Knowledge Graphs with SPARQL) in the openHPI Course **Knowledge Graphs 2023**.
#
# In this colab notebook you will learn how to query the Wikidata Knowledge Graph.
#
# *Please make a copy of this notebook to try out your own adaptions via "File -> Save Copy in Drive"*

# %% [markdown]
# ### Querying Wikidata with mkwikidata ###
#
# [mkwikidata](https://pypi.org/project/mkwikidata/#description) is a package for running SPARQL queries on Wikidata
#
# We have to install the following packages:
#
# **mkwikidata**

# %%
# !pip install mkwikidata
# Out:
# Collecting mkwikidata
#   Downloading mkwikidata-0.14-py2.py3-none-any.whl.metadata (741 bytes)
# Requirement already satisfied: requests>=2.25.1 in /usr/local/lib/python3.11/dist-packages (from mkwikidata) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.1->mkwikidata) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.1->mkwikidata) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.1->mkwikidata) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.1->mkwikidata) (2025.6.15)
# Downloading mkwikidata-0.14-py2.py3-none-any.whl (3.0 kB)
# Installing collected packages: mkwikidata
# Successfully installed mkwikidata-0.14

# %%
import mkwikidata, pprint
import pandas as pd

# %% [markdown]
# #### **Query 1**:  Show all narrated cities of books and literary works and their geo coordination in Wikidata
#
# Following Wikidata classes/instances and properties are required:
#
# [wd:Q571](https://www.wikidata.org/wiki/Q571), [wd:Q7725634](https://www.wikidata.org/wiki/Q7725634), [wd:Q515](https://www.wikidata.org/wiki/Q515),  [wdt:P31](https://www.wikidata.org/wiki/Property:P31), [wdt:P840](https://www.wikidata.org/wiki/Property:P840), [wdt:P625](https://www.wikidata.org/wiki/Property:P625) , [wdt:P279](https://www.wikidata.org/wiki/Property:P279)

# %%
query = """
SELECT ?label ?placelabel ?coord
WHERE
{
  VALUES ?type {wd:Q571 wd:Q7725634} #book or literary work
  # ?item wdt:P31 ?type . #of type ?type
  # ?item rdfs:label ?label FILTER (lang(?label) = "en") .
  # ?item wdt:P840 ?place . #narration place ?place
  # ?place wdt:P31/wdt:P279* wd:Q515 . # place is an instance or a subclass of city
  # ?place wdt:P625 ?coord . #has coordinations ?ccord
  # ?place rdfs:label ?placelabel FILTER (lang(?placelabel) = "en") .
}
"""
query_result = mkwikidata.run_query(query, params={ })
query_result
# Out:
# {'head': {'vars': ['label', 'placelabel', 'coord']},
#  'results': {'bindings': [{'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-1.9025 52.48)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "The Rotters' Club"},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Birmingham'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-1.9025 52.48)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "Felicia's Journey"},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Birmingham'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-1.9025 52.48)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Living'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Birmingham'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-1.9025 52.48)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Rebels and Traitors'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Birmingham'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-1.9025 52.48)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'What Hetty Did'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Birmingham'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-1.9025 52.48)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'What Was Lost'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Birmingham'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(45.341944444 2.039166666)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Adventures of Amina al-Sirafi'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mogadishu'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(45.341944444 2.039166666)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Crossbones'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mogadishu'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(45.341944444 2.039166666)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Links: A Novel'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mogadishu'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(45.341944444 2.039166666)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Knots: A novel'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mogadishu'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Bay of Noon'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Amok'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Candelaio'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Filumena Marturano'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Pentamerone'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Devil in Love'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Trickster of Seville and the Stone Guest'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-4.25 55.861111111)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Men Should Weep'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Glasgow'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-4.25 55.861111111)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Great Cauldron'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Glasgow'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-4.25 55.861111111)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Shuggie Bain'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Glasgow'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-4.25 55.861111111)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Young Mungo'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Glasgow'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(72.84 21.205)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Indian Dreams'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Surat'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(138.6 -34.9275)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Journals of Expeditions of Discovery into Central Australia'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Adelaide'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(138.6 -34.9275)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Reconnoitering Voyages and Travels, with Adventures in the new colonies of South Australia'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Adelaide'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(12.242219444 45.672219444)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Il cielo è rosso'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Treviso'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-4.033333333 39.866666666)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Club Dumas'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Toledo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-4.033333333 39.866666666)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'La Villana'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Toledo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-4.033333333 39.866666666)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Segundo tomo del ingenioso hidalgo don Quixote de La Mancha'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Toledo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-4.033333333 39.866666666)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Kiss'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Toledo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-4.033333333 39.866666666)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'La ajorca de oro'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Toledo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-4.033333333 39.866666666)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'La dama de armiño'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Toledo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-4.033333333 39.866666666)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Ángel Guerra'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Toledo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-4.033333333 39.866666666)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Christ of the skull'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Toledo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-4.033333333 39.866666666)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Pit and the Pendulum'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Toledo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-4.033333333 39.866666666)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'La ilustre fregona'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Toledo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-4.033333333 39.866666666)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Die Jüdin von Toledo'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Toledo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-4.033333333 39.866666666)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Lazarillo de Tormes'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Toledo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Caviar and lentils'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Elegia di Madonna Fiammetta'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Il marito di Elena'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Saturday Sunday Monday'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Wounded to Death'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(13.361261944 38.115658055)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'House of Liars'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Palermo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(13.361261944 38.115658055)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Florios of Sicily'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Palermo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(5.570555555 50.639722222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Maigret at the Gai-Moulin'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Liège'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(13.361261944 38.115658055)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'I Beati Paoli'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Palermo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(13.361261944 38.115658055)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Silent Duchess'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Palermo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(12.6372 43.725238888)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Road to Rome'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Urbino'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(11.331388888 43.318333333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Tale of Two Lovers'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Siena'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-47.882777777 -15.793888888)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Nakur Babu o El Dorado'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Brasília'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-77.0375 -12.06)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Conversation in The Cathedral'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Lima'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-77.0375 -12.06)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Aunt Julia and the Scriptwriter'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Lima'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-77.0375 -12.06)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'A World for Julius'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Lima'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-77.0375 -12.06)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Blanca Sol'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Lima'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-77.0375 -12.06)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'El loco de los balcones'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Lima'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'L.A. Requiem'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Lady in the Lake'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'I Am Legend'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-77.0375 -12.06)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Martin Paz'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Lima'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-77.0375 -12.06)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Bad Girl'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Lima'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(114.158611111 22.278333333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Tintorettor Jishu'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hong Kong'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(114.158611111 22.278333333)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Bullet Time'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hong Kong'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'House of Leaves'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Last Coyote'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(114.158611111 22.278333333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Painted Veil'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hong Kong'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(114.158611111 22.278333333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Around the World in Eighty Days'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hong Kong'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Snow Crash'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Flow My Tears, the Policeman Said'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Savage Detectives'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(1.855555555 50.9475)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Three Musketeers'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Calais'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'L’aventurier françois'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Les arts et l’amitié'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Brick Bolding'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': "Naples '44"},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Buio'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'My Brilliant Friend'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Vipera'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Story of a New Name'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(114.158611111 22.278333333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Fragrant Harbour'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hong Kong'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(114.158611111 22.278333333)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Kowloon Tong'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hong Kong'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(114.158611111 22.278333333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Music on the Bamboo Radio'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hong Kong'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(114.158611111 22.278333333)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Monkey King'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hong Kong'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(114.158611111 22.278333333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Mystery of the Fire Dragon'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hong Kong'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(114.158611111 22.278333333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Pacific Between'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hong Kong'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(114.158611111 22.278333333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Piano Teacher'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hong Kong'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'I bastardi di Pizzofalcone'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Usi e costumi di Napoli e contorni descritti e dipinti. (1853-58 edition)'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Cuccioli'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Those Who Leave and Those Who Stay'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Story of the Lost Child'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Memoirs of Loise De Rosa'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'La dama di piazza'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Lying Life of Adults'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Day of the Dead'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(4.808333333 43.948611111)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Enfans de Loyola'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Avignon'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(4.808333333 43.948611111)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Sans Famille'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Avignon'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(4.808333333 43.948611111)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "Mémoires d'un touriste"},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Avignon'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(4.808333333 43.948611111)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Antonin'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Avignon'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(69.165833333 34.532777777)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'And the Mountains Echoed'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Kabul'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(7.55 44.383333333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Light Words between Us'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Cuneo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-4.033333333 39.866666666)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Voyage en Espagne'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Toledo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(0.335277777 46.581111111)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Lettres de madame de G***'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Poitiers'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(1.855555555 50.9475)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Nouveau voyage sentimental'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Calais'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(1.855555555 50.9475)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'L’enfant du carnaval'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Calais'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(1.855555555 50.9475)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Adélaïde'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Calais'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-78.5125 -0.22)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'More Things in Heaven'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Quito'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-78.5125 -0.22)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Salvo el calvario'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Quito'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-78.5125 -0.22)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Ciudad de invierno'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Quito'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-78.5125 -0.22)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Angelote, amor mío'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Quito'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-78.5125 -0.22)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Siberia'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Quito'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-78.5125 -0.22)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Débora'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Quito'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-78.5125 -0.22)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Aprendiendo a morir'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Quito'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-78.5125 -0.22)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Gabriel(a)'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Quito'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-78.5125 -0.22)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Por qué Jesús no vuelve'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Quito'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-78.5125 -0.22)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Pequeños palacios en el pecho'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Quito'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Suicide Hill'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'A Darkness More Than Night'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Big Sleep'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Less Than Zero'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-1.516666666 52.416666666)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Facts of Life'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Coventry'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-1.516666666 52.416666666)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Tooth Fairy'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Coventry'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(69.165833333 34.532777777)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Shabnam'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Kabul'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Rising Sun'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Dr. Adder'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(3.224166666 51.208888888)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "L'Oeuvre au noir"},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Bruges'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(3.224166666 51.208888888)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Holy Sinner'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Bruges'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(17.116666666 39.083333333)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Fondo Gesù'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Crotone'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-4.033333333 39.866666666)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'La catedral'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Toledo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-4.033333333 39.866666666)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'A Town without A King'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Toledo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(9.99155 48.39841)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Beggar'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Ulm'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-57.633333333 -25.3)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Things We Lost in the Fire'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Asunción'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(9.929444444 49.794444444)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Yalu Flows'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Würzburg'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-88.7675 17.25)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Actual Star'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Belmopan'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(13.234444444 -8.838333333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Savage Detectives'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Luanda'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(11.6175 44.839166666)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Five Stories of Ferrara'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Ferrara'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Face'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Fifth Witness'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Gods of Guilt'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Grifters'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The New Centurions'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Old Reliable'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Revolt of the Cockroach People'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Scarlet Thread'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Sea Came in at Midnight'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Temperamentals'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Three Roads'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Valley-Westside War'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The White Boy Shuffle'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Zoot-Suit Murders'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-118.24368 34.05223)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Their Dogs Came with Them'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Los Angeles'}},
# ...
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(26.57361 41.67304)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "Ikonija, vizier's mother: a short story from 17th century"},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Edirne'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(26.57361 41.67304)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'A monk and a hajduk: a short story about the last days of Serbia in the 15th century'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Edirne'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(26.57361 41.67304)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "Koča's froniter: a historical novel"},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Edirne'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(26.57361 41.67304)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Legion of death: a novel from the Balkan War 1912/1913. (written by Branislav Jurišić)'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Edirne'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(78.02 27.18)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Indian Dreams'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Agra'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(34.786666666 31.252222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Savage Detectives'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Beersheba'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(7.102222222 50.735277777)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'An Ace Up My Sleeve'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Bonn'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(7.102222222 50.735277777)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Kraft'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Bonn'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(10.738888888 59.913333333)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Thirst'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Oslo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(10.738888888 59.913333333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Tante Ulrikkes Vei'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Oslo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(10.738888888 59.913333333)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Knife'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Oslo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(10.738888888 59.913333333)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Killing Moon'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Oslo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(10.738888888 59.913333333)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'North of Dawn'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Oslo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-1.470277777 53.380833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Northern Clemency'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Sheffield'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-79.8875 -2.19)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Las tres ratas'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Guayaquil'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-79.8875 -2.19)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Incendiamos las yeguas en la madrugada'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Guayaquil'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-79.8875 -2.19)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Eses fatales'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Guayaquil'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-79.8875 -2.19)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'El muelle'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Guayaquil'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-79.8875 -2.19)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Chumbote'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Guayaquil'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Northern Lights'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Brave New World'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(9.67 45.695)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'La Farfalla'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Bergamo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': "Bruno's Dream"},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Phoenix and the Carpet'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mockymen'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Good Apprentice'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Eye of God'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Eye of Osiris'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Shadow in the North'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Death-Watch'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Magic Toyshop'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Offshore'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Rises the Night'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Mary Poppins Opens the Door'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Millennium People'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Death of Jezebel'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Gas Light'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Gents'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': "Gideon's Day"},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Gone Too Far!'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Good News, Bad News'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Goodbye Piccadilly, Farewell Leicester Square'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Gridlock'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Griffin and Sabine'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Gym and Slimline'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Harare North'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hawksmoor'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Headhunters'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Heligoland'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hide My Eyes'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Tell me who I am'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    ...]}}

# %% [markdown]
# The json_normalize() function is used to convert the JSON string into a DataFrame for a more (human)readable output

# %%
#from pandas import json_normalize
results_df = pd.json_normalize(query_result['results']['bindings'])
results_df[['label.value', 'placelabel.value', 'coord.value']]
# Out:
#                 label.value placelabel.value                       coord.value
# 0         The Rotters' Club       Birmingham              Point(-1.9025 52.48)
# 1         Felicia's Journey       Birmingham              Point(-1.9025 52.48)
# 2                    Living       Birmingham              Point(-1.9025 52.48)
# 3       Rebels and Traitors       Birmingham              Point(-1.9025 52.48)
# 4            What Hetty Did       Birmingham              Point(-1.9025 52.48)
# ...                     ...              ...                               ...
# 16944  Dobbeltspil i Odessa          Baghdad  Point(44.366111111 33.315277777)
# 16945     Geography of Fear         Helsinki       Point(24.9375 60.170833333)
# 16946                 Fanny        Marseille   Point(5.376388888 43.296666666)
# 16947            Zénothémis        Marseille   Point(5.376388888 43.296666666)
# 16948           Högspänning       Gothenburg            Point(11.9675 57.7075)
#
# [16949 rows x 3 columns]

# %% [markdown]
# Let's [visualize the query](https://query.wikidata.org/#%23defaultView%3AMap%0ASELECT%20%3Flabel%20%3Fplacelabel%20%3Fcoord%0AWHERE%0A%7B%0A%20%20VALUES%20%3Ftype%20%7Bwd%3AQ571%20wd%3AQ7725634%7D%20%20%23%20book%20or%20literary%20work%0A%20%20%3Fitem%20wdt%3AP31%20%3Ftype%20.%0A%20%20%3Fitem%20rdfs%3Alabel%20%3Flabel%20FILTER%20%28lang%28%3Flabel%29%20%3D%20%22en%22%29%20.%0A%20%20%3Fitem%20wdt%3AP840%20%3Fplace%20.%20%20%23%20narration%20place%20is%20%3Fplace%0A%20%20%3Fplace%20wdt%3AP625%20%3Fcoord%20.%0A%20%20%3Fplace%20rdfs%3Alabel%20%3Fplacelabel%20FILTER%20%28lang%28%3Fplacelabel%29%20%3D%20%22en%22%29%20.%0A%7D%20%0A) result in Wikidata Query Service\!

# %% [markdown]
# #### **Query 2**: What is the most common narration country in Wikidata books and literature works? ####
#
# Following additional Wikidata classes/instances and properties are required:
#
# [wdt:P17](https://www.wikidata.org/wiki/Property:P17)

# %%
query = """
SELECT ?countrylabel (COUNT(?country) AS ?count)
WHERE
{
  VALUES ?type {wd:Q571 wd:Q7725634}  # book or literary work
  # ?item wdt:P31 ?type .
  # ?item wdt:P840 ?place . # narration place is ?place
  # ?place wdt:P17 ?country .
  # ?country rdfs:label ?countrylabel FILTER (lang(?countrylabel) = "en") .

}
  GROUP BY ?countrylabel
  ORDER BY DESC(?count)

"""
query_result = mkwikidata.run_query(query, params={ })
results_df = pd.json_normalize(query_result['results']['bindings'])
results_df[['countrylabel.value', 'count.value']]
# Out:
#               countrylabel.value count.value
# 0                  United States        2981
# 1                 United Kingdom        1802
# 2                         France        1587
# 3                          Italy         956
# 4                          Spain         658
# ..                           ...         ...
# 372         Duchy of Württemberg           1
# 373        County of Württemberg           1
# 374       Kingdom of Württemberg           1
# 375                  Kievan Rus'           1
# 376  realm of the United Kingdom           1
#
# [377 rows x 2 columns]

# %% [markdown]
# Let's try out the bubble chart visualization of [the query result](https://query.wikidata.org/#%23defaultView%3ABubbleChart%0ASELECT%20%3Fcountrylabel%20%28COUNT%28%3Fcountry%29%20AS%20%3Fcount%29%0AWHERE%0A%7B%0A%20%20VALUES%20%3Ftype%20%7Bwd%3AQ571%20wd%3AQ7725634%7D%20%20%23%20book%20or%20literary%20work%0A%20%20%3Fitem%20wdt%3AP31%20%3Ftype%20.%0A%20%20%3Fitem%20wdt%3AP840%20%3Fplace%20.%20%23%20narration%20place%20is%20%3Fplace%0A%20%20%3Fplace%20wdt%3AP17%20%3Fcountry%20.%0A%20%20%3Fcountry%20rdfs%3Alabel%20%3Fcountrylabel%20FILTER%20%28lang%28%3Fcountrylabel%29%20%3D%20%22en%22%29%20.%0A%0A%7D%20%0A%20%20GROUP%20BY%20%3Fcountrylabel%0A%20%20ORDER%20BY%20DESC%28%3Fcount%29%0A) in Wikidata!

# %% [markdown]
# ### Querying Wikidata with SPARQLWrapper ###
#
# Alternatively, Wikidata KG and other KGs can be queried using the [SPARQLWrapper](https://sparqlwrapper.readthedocs.io/en/latest/main.html) – a python interface for any SPARQL Endpoint.
#
# For this, we have to install and import the following packages:
#
#
# **SPARQLWrapper**

# %%
# !pip install -q sparqlwrapper    #install SPARQLwrapper
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 565.1/565.1 kB 10.2 MB/s eta 0:00:00

# %%
from SPARQLWrapper import SPARQLWrapper, JSON, XML, RDF

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql") #determine SPARQL endpoint
sparql.setReturnFormat(JSON) #determine the output format

# %% [markdown]
# #### **Query 3**: Being a writer is dangerous! Let's see what is the most common cause of death among writers? ####
#
# Following additional Wikidata classes/instances and properties are required:
#
# [wdt:P106](https://www.wikidata.org/wiki/Property:P106), [wdt:509](https://www.wikidata.org/wiki/Property:P509), [wd:Q36180](https://www.wikidata.org/wiki/Q36180)

# %%
sparql.setQuery("""
SELECT ?cause ?causeLabel (COUNT(?person) AS ?count)
WHERE
{
  # ?person wdt:P106 wd:Q36180 . #occupation writer
  # ?person wdt:P509 ?cause . #?cause is a death cause
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
}
GROUP BY ?cause ?causeLabel
HAVING(?count > 1)
ORDER BY DESC(?count)
 """
)
results = sparql.query().convert()   # execute SPARQL query and write result to "results"
results_df = pd.json_normalize(results['results']['bindings'])
results_df[['causeLabel.value', 'count.value']]
# Out:
#             causeLabel.value count.value
# 0                     cancer        1161
# 1      myocardial infarction        1156
# 2               tuberculosis         586
# 3                  pneumonia         578
# 4                     stroke         474
# ..                       ...         ...
# 303  death from scuba diving           2
# 304                     CaVe           2
# 305                Q78698047           2
# 306      equestrian accident           2
# 307          ischemic stroke           2
#
# [308 rows x 2 columns]

# %% [markdown]
# #### **Query 4**: And if we talk about writers that died before 1800? ####
#
# Following additional Wikidata classes/instances and properties are required:
#
# [wdt:P570](https://www.wikidata.org/wiki/Property:P570)

# %%
sparql.setQuery("""
SELECT ?cause ?causeLabel (COUNT(?person) AS ?count)
WHERE
{
  # ?person wdt:P106 wd:Q36180; #ocupation writer
          wdt:P509 ?cause ; #?cause is a death cause
          wdt:P570 ?date . #death date
  FILTER (?date < "1800-01-01T00:00:00Z"^^xsd:dateTime) .
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
}
GROUP BY ?cause ?causeLabel
HAVING(?count > 1)
ORDER BY DESC(?count)

 """
)
results = sparql.query().convert()   # execute SPARQL query and write result to "results"
results_df = pd.json_normalize(results['results']['bindings'])
results_df[['causeLabel.value', 'count.value']]
# Out:
#                             causeLabel.value count.value
# 0                               decapitation          91
# 1                                     plague          63
# 2                                    disease          55
# 3                               tuberculosis          47
# 4                           death by burning          35
# 5                                   drowning          31
# 6                                    hanging          24
# 7                                   smallpox          23
# 8                                     stroke          22
# 9                                    malaria          16
# 10                          killed in action          16
# 11                                 pneumonia          12
# 12                                    poison          12
# 13                            exsanguination          11
# 14                                     edema           7
# 15                                horse fall           7
# 16                                stab wound           7
# 17                       puerperal disorders           7
# 18                   cerebrovascular disease           6
# 19                              intoxication           6
# 20                     myocardial infarction           5
# 21                                   leprosy           5
# 22                                 poisoning           5
# 23                                 dysentery           5
# 24                                  stabbing           5
# 25                       falling from height           5
# 26  hanged, drawn, quartered and decapitated           4
# 27                                   flaying           4
# 28                                  apoplexy           4
# 29                        infectious disease           4
# 30                                    cancer           3
# 31                                  syphilis           3
# 32                                    typhus           3
# 33                             gunshot wound           3
# 34                                     fever           2
# 35                                  epidemic           2
# 36                               Black Death           2
# 37                                   measles           2
# 38                              inflammation           2
# 39                             breast cancer           2
# 40                                   seppuku           2
# 41                                    sepsis           2
# 42                            stomach cancer           2
# 43                            bubonic plague           2
# 44                               peritonitis           2
# 45                                   falling           2
# 46                            kidney failure           2
# 47                                     abuse           2
# 48                                starvation           2
# 49                             incarceration           2
# 50                                strangling           2
# 51                       cerebral hemorrhage           2
# 52           gastrointestinal system disease           2
# 53                               crucifixion           2
# 54                             assassination           2
# 55                                 execution           2
# 56                       death from laughter           2
# 57                          lightning strike           2

# %% [markdown]
# So, being a writer before 1800 could often leave you without the head. :)

# %% [markdown]
# Explore more!
#
#
#
# *   What was the worst year for writers? [List years](https://query.wikidata.org/#SELECT%20%3Fyear%20%28COUNT%28%3Fperson%29%20AS%20%3Fcount%29%0AWHERE%0A%7B%0A%20%20%3Fperson%20wdt%3AP106%20wd%3AQ36180%3B%0A%20%20%20%20%20%20%20%20%20%20wdt%3AP509%20wd%3AQ204933%20%3B%0A%20%20%20%20%20%20%20%20%20%20wdt%3AP570%20%3Fdate%20.%0A%20%20BIND%20%28YEAR%28%3Fdate%29%20AS%20%3Fyear%29%0A%7D%0AGROUP%20BY%20%3Fyear%0AORDER%20BY%20DESC%28%3Fcount%29%0A) in which the most writers were decapitated.
# *   What is [the most dangerous month](https://query.wikidata.org/#SELECT%20%3Fmonth%20%28COUNT%28%3Fperson%29%20AS%20%3Fcount%29%0AWHERE%0A%7B%0A%20%20%3Fperson%20wdt%3AP106%20wd%3AQ36180%3B%0A%20%20%20%20%20%20%20%20%20%20wdt%3AP509%20wd%3AQ468455%20%3B%0A%20%20%20%20%20%20%20%20%20%20wdt%3AP570%20%3Fdate%20.%0A%20%20BIND%20%28MONTH%28%3Fdate%29%20AS%20%3Fmonth%29%0A%7D%0AGROUP%20BY%20%3Fmonth%0AORDER%20BY%20DESC%28%3Fcount%29%0A) for writers to be burnt?
#
# *  [Show the images](https://query.wikidata.org/#%23defaultView%3AImageGrid%0ASELECT%20%3Fperson%20%3Fimage%0AWHERE%0A%7B%0A%20%20%3Fperson%20wdt%3AP106%20wd%3AQ36180%3B%0A%20%20%20%20%20%20%20%20%20%20wdt%3AP509%20wd%3AQ12242142%20%3B%0AOPTIONAL%20%7B%20%3Fperson%20wdt%3AP18%20%3Fimage%20%7D%0A%7D%0A%0A) of writers who died from laughter.
#
#
#
# *   Explore more and share your interesting queries and findings with us! :)

# %% [markdown]
# #### **Query 5**: Now let's see how writers tend to kill their characters. ####
#
# Following additional Wikidata classes/instances and properties are required:
#
# [wdt:P674](https://www.wikidata.org/wiki/Property:P674)

# %%
sparql.setQuery("""
SELECT ?cause ?causeLabel (COUNT(?character) AS ?count)

WHERE
{
  VALUES ?type {wd:Q571 wd:Q7725634}  # book or literary work
  # ?item wdt:P31 ?type .
  # ?item wdt:P674 ?character .
  # ?character wdt:P509 ?cause .
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
}
GROUP BY ?cause ?causeLabel
HAVING(?count > 1)
ORDER BY DESC(?count)

 """
)
results = sparql.query().convert()   # execute SPARQL query and write result to "results"
results_df = pd.json_normalize(results['results']['bindings'])
results_df[['causeLabel.value', 'count.value']]
# Out:
#      causeLabel.value count.value
# 0        decapitation          68
# 1    killed in action          58
# 2       gunshot wound          56
# 3              stroke          27
# 4        tuberculosis          24
# ..                ...         ...
# 89       liver cancer           2
# 90            garrote           2
# 91             combat           2
# 92      assassination           2
# 93  aviation accident           2
#
# [94 rows x 2 columns]

# %% [markdown]
# #### **Query 6**: In the end, let's take a look at the authors that are still alive! List 100 youngest authors alive from the Eastern Europe. ####

# %%
sparql.setQuery("""
SELECT DISTINCT ?personLabel ?countryLabel ?age
WHERE {
  # ?person wdt:P106 wd:Q36180 ; #occupation writer
          wdt:P27 ?country ; #country of citizenship
          wdt:P569 ?birth_date.

  BIND(year(now()) - year(?birth_date) AS ?age)
  FILTER NOT EXISTS { ?person wdt:P570 ?death } #no death date for this person exist

  # ?country wdt:P361 wd:Q27468 . #country is a part of Easter Europe

  SERVICE wikibase:label {
    bd:serviceParam wikibase:language "en". }
 }

ORDER BY (?age)
LIMIT 100

 """
)
results = sparql.query().convert()   # execute SPARQL query and write result to "results"
results_df = pd.json_normalize(results['results']['bindings'])
results_df[['personLabel.value', 'countryLabel.value', 'age.value']]
# Out:
#     personLabel.value countryLabel.value age.value
# 0       Silva Souriau            Romania       NaN
# 1     Faina Savenkova             Russia        17
# 2         Vojta Horák     Czech Republic        17
# 3   Magdaléna Paťhová     Czech Republic        17
# 4              Pokich             Russia        18
# ..                ...                ...       ...
# 95          Q97276089            Ukraine        31
# 96       Dorota Kotas             Poland        31
# 97       Jiří Vítovec     Czech Republic        31
# 98        Filip Starý     Czech Republic        31
# 99     Lucie Kučerová     Czech Republic        31
#
# [100 rows x 3 columns]
